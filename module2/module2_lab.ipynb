# %%
name = "Ana"
hourly_wage = 20.0
hours = 40
weekly_pay = hourly_wage * hours
print(name + " earns " + str(weekly_pay) + " per week.")
# Out:
# Ana earns 800.0 per week.

# %%
#List of tempatures
temps = [61, 65, 72, 58, 70, 74, 68]
count = 0
for temp in temps:
    if temp > 65:
        count = count + 1
print(count)
# Out:
# 4

# %%
temps = [61, 65, 72, 58, 70, 74, 68]
def to_celsius(f):
    return (f-32) * 5/9
print(round(to_celsius(temps[0]), 1))
# Out:
# 16.1

# %%
movie = {"title": "Oppenhiemer", "year" : 2023, "rating" : 8.2}
for key, value in movie.items():
    print(key, ":", value)
# Out:
# title : Oppenhiemer
# year : 2023
# rating : 8.2

# %%
import pandas as pd
df = pd.read_csv("chickwts.csv")
df.describe()
# Out:
#        Unnamed: 0      weight
# count   71.000000   71.000000
# mean    36.000000  261.309859
# std     20.639767   78.073700
# min      1.000000  108.000000
# 25%     18.500000  204.500000
# 50%     36.000000  258.000000
# 75%     53.500000  323.500000
# max     71.000000  423.000000

# %%
#It shows the lowest to the highest weight, as well as the mean, max, and min. Whats suprising is the 25%,
#50%, and the 75%. It shows the average weight in those percentiles.
