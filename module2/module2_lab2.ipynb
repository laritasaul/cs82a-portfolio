# %%
num_1 = 5
num_2 = 8

total = 0
for num in range(num_2):
    
        total = total + num_1
    
print (total)
# Out:
# 40

# %%
num_1, num_2 = 5, 8
count = 0
total = 0
while (num_2 > count):
    total = total + num_1
    count = count + 1
print(total)
# Out:
# 40
